# %%
# !pip install langchain
# !pip install openai
# Out:
# Requirement already satisfied: langchain in c:\users\user\anaconda3\lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\users\user\anaconda3\lib\site-packages (from langchain) (1.2.28)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in c:\users\user\anaconda3\lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\user\anaconda3\lib\site-packages (from langchain) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.29)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (24.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (8.2.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\user\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in c:\users\user\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in c:\users\user\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\user\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.20.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (2.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\user\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\user\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.27.0)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\user\anaconda3\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.2.0)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.2)
# Requirement already satisfied: idna in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.7)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.2.3)
# Requirement already satisfied: openai in c:\users\user\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\user\anaconda3\lib\site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\user\anaconda3\lib\site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in c:\users\user\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\user\anaconda3\lib\site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\user\anaconda3\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\user\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate

# %% [markdown]
# # Task 1: Replace Hardcoded Prompts

# %%
def explain_topic(topic):
   return f"Explain {topic} in simple terms for beginners"

# %%
template = "Explain {topic} in simple terms for beginners"

prompt = PromptTemplate(
    input_variables=["topic"],
    template=template
)

output = prompt.format(topic="Machine Learning")

print(output)
# Out:
# Explain Machine Learning in simple terms for beginners

# %% [markdown]
# # Task 2: Multi-Input Prompt System

# %%
template = """
Explain {topic} for {audience} in a {tone} tone
"""

multi_prompt = PromptTemplate(
    input_variables=["topic","audience","tone"],
    template=template
)

print(multi_prompt.format(
    topic="AI",
    audience="beginners",
    tone="friendly"
))

print(multi_prompt.format(
    topic="Python",
    audience="kids",
    tone="fun"
))

print(multi_prompt.format(
    topic="Deep Learning",
    audience="engineers",
    tone="technical"
))
# Out:
# Explain AI for beginners in a friendly tone
#
#
# Explain Python for kids in a fun tone
#
#
# Explain Deep Learning for engineers in a technical tone

# %% [markdown]
# # Task 3: Prompt Variations Engine

# %%
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

print(teaching_template.format(topic="Machine Learning"))
# Out:
# Explain Machine Learning clearly step by step

# %%
interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

print(interview_template.format(topic="Machine Learning"))
# Out:
# Ask 3 interview questions about Machine Learning

# %%
story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

print(story_template.format(topic="Machine Learning"))
# Out:
# Explain Machine Learning as a story

# %% [markdown]
# # Task 4: ChatPromptTemplate System

# %%
chat_template = ChatPromptTemplate.from_messages([
    ("system","You are a {role}"),
    ("user","Explain {topic}")
])

messages = chat_template.format_messages(
    role="teacher",
    topic="Neural Networks"
)

print(messages)
# Out:
# [SystemMessage(content='You are a teacher', additional_kwargs={}, response_metadata={}), HumanMessage(content='Explain Neural Networks', additional_kwargs={}, response_metadata={})]

# %%
messages = chat_template.format_messages(
    role="interviewer",
    topic="Neural Networks"
)

print(messages)
# Out:
# [SystemMessage(content='You are a interviewer', additional_kwargs={}, response_metadata={}), HumanMessage(content='Explain Neural Networks', additional_kwargs={}, response_metadata={})]

# %%
messages = chat_template.format_messages(
    role="motivator",
    topic="Neural Networks"
)

print(messages)
# Out:
# [SystemMessage(content='You are a motivator', additional_kwargs={}, response_metadata={}), HumanMessage(content='Explain Neural Networks', additional_kwargs={}, response_metadata={})]

# %% [markdown]
# # Task 5: Input Validation Layer

# %%
def validate_inputs(audience, tone):

    valid_audience = ["beginner","intermediate","expert"]

    valid_tone = ["formal","casual","fun"]

    if audience not in valid_audience:
        audience = "beginner"

    if tone not in valid_tone:
        tone = "formal"

    return audience, tone

# %%
a,t = validate_inputs("kids","friendly")

print(a)
print(t)
# Out:
# beginner
# formal

# %% [markdown]
# # Task 6: Prompt Generator App

# %%
def generate_prompt(topic,audience,tone,style):

    audience,tone = validate_inputs(audience,tone)

    if style == "teaching":

        template = PromptTemplate(
            input_variables=["topic","audience","tone"],
            template="""
Explain {topic} for {audience}
in a {tone} teaching style
"""
        )

    elif style == "interview":

        template = PromptTemplate(
            input_variables=["topic"],
            template="Ask interview questions about {topic}"
        )

    else:

        template = PromptTemplate(
            input_variables=["topic"],
            template="Explain {topic} as a storytelling concept"
        )

    return template.format(
        topic=topic,
        audience=audience,
        tone=tone
    )

# %%
print(generate_prompt(
    "Neural Networks",
    "beginner",
    "fun",
    "teaching"
))
# Out:
# Explain Neural Networks for beginner
# in a fun teaching style

# %% [markdown]
# # Task 7: Template Reusability Test

# %%
template = PromptTemplate(

    input_variables=["topic"],

    template="Explain {topic} simply"
)

topics = [

"AI",
"Python",
"NLP",
"Deep Learning",
"Transformers"

]

for t in topics:

    print(template.format(topic=t))
# Out:
# Explain AI simply
# Explain Python simply
# Explain NLP simply
# Explain Deep Learning simply
# Explain Transformers simply
